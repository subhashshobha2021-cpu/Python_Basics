# %% [markdown]
# What is Object-Oriented Programming (OOP)?
#
# OOP is the concept in programming where you can create a seperate code which is known as class and create object which will be reusable.
# It means that we are creating a specific code which can be re-used multiple times in a particular class.
#
# What is a class in OOP+
#
# Class is known as blueprint or template to create objects in OOPS. It also used to define the properties of the object available.
#
# What is an object in OOP+
#
# Object is simply the code written in OOP which will be called upon to re-use whenever it is required
#
# What is the difference between abstraction and encapsulation?
#
# Abstraction is the concept to hide the complex/unrequired code and showing the required code
# Encapsulation is the proprty of object where we can hide the method/code and we can do it 2 option:
# 1. __ making it private
# 2_ making it protected
#
# What are dunder methods in Python?
#
# Dunder methods are the built-in methods in python. they are also known as magic methods. Ex- __init__ is dunder method
#
# Explain the concept of inheritance in OOP?
#
# The word inheritance means that getting the similarity of someone. In OOPS, intheritance refers to the method when 1 functions inherited the property of another function as child
#
# What is polymorphism in OOP?
#
# Polymorphism refers to the object taking several form with respect to the data
#
# How is encapsulation achieved in Python?
#
# Encapsulation can be achieved with 2 methods in pyton
# Applying __(double underscore at beginning and end of function)
# self._private_method__()
# self_protected_method_()
#
# What is a constructor in Python?
#
# A constructor in Python is a special method used to initialize the state (attributes) of an object when it is created.
#
# What are class and static methods in Python?
#
# Class methods are used in OOPS when it is bound to the class only, where static methods are not bound to class and use freely
#
#
# What is method overloading in Python?
#
# Method overloading is concept where function is created to support different input variables
#
# What is method overriding in OOP?
#
# Method overriding is the concept where same function has been written in different classes or methods. It will take the property of the parent class
#
# What is a property decorator in Python?
#
# Property decorater allows the methods to be accessed as attributes.
#
#
# Why is polymorphism important in OOP?
#
# Polymorphism refers to to the concept where function has taken multiple forms with respect to data.
#
# What is an abstract class in Python+
#
# It is the concept where developer hides the critical or un-necessary information from the user and showing only the required information
#
# What are the advantages of OOP?
#
# Object-Oriented Programming (OOP) advantages include better code organization (modularity, encapsulation), reusability via inheritance, flexibility through polymorphism, easier maintenance and debugging, improved security, and scalability, all by modeling real-world entities as self-contained "objects". This leads to less redundant code, faster development, and more robust, manageable software, especially for large systems.
#
# What is the difference between a class variable and an instance variable?
#
# Classs variable can be used within the class,however, instance variable can be used for specific instances
#
# What is multiple inheritance in Python?
#
# Inheritance is concept where a function is taking the property of his parent class. When a class inheriting the property of multiple classes. It is known as multiple inheritance
#
#
# Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?
# If a class defines __repr__ but not __str__, str() and print() will fall back to using the output of __repr__. However, if __str__ is defined, it is always preferred for human-facing output [1]. It is considered a best practice to always define __repr__ for custom classes, as it provides valuable debugging information, and defining __str__ is optional but recommended for user-friendly output
#
#
# What is the significance of the ‘super()’ function in Python?
# The super() function in Python is a built-in function primarily used in object-oriented programming to grant access to methods and properties of a parent or sibling class
#
# What is the significance of the __del__ method in Python?
# The __del__ method in Python, also known as the destructor, defines the code to be executed when an instance of a class is about to be destroyed (garbage collected). Its primary significance lies in allowing objects to perform necessary cleanup operations before their memory is reclaimed.
#
#
# What is the difference between @staticmethod and @classmethod in Python?
# Class methods are bound to the class for accessing/modifying the functions where static methods bevaves like a plan function and does not take "Self" as input
#
#
# How does polymorphism work in Python with inheritance?
# In Python, polymorphism with inheritance is primarily achieved through method overriding, a form of runtime polymorphism (also known as dynamic binding)
#
# What is method chaining in Python OOP?
# Method chaining is an object-oriented programming (OOP) technique that allows you to call multiple methods on the same object in a single, sequential line of code. Each method in the chain performs an action and then returns the object itself (usually self), allowing the next method to be called on that returned object without the need for intermediate variables.
#
# What is the purpose of the __call__ method in Python?
# The purpose of the __call__ method in Python is to make an instance of a class callable, meaning it can be treated and invoked like a function

# %%
2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
from it and implement the area() method in both

3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
and further derive a class ElectricCar that adds a battery attribute.

4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
Sparrow and Penguin that override the fly() method.


5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
balance and methods to deposit, withdraw, and check balance

6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
and Piano that implement their own version of play().

7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
method subtract_numbers() to subtract two numbers.

8. Implement a class Person with a class method to count the total number of persons created


9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
fraction as "numerator/denominator".

# %%
1.#  Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!
class Animal:
  def Speak(Self):
    print("Animal Sound")

class Dog(Animal):
  def Speak(self):
    print("Bark!")

# %%
from abc import abstractclassmethod
# Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both

class Shape:
  @abstractclassmethod
  def area(self):
    pass

class Circle(Shape):
  def __init__(self, radius):
    self.radius = radius
  def area(self):
    a = 3.14*self.radius**2
    return a
class Rectangle(Shape):
  def __init__(self, l,b):
    self.l = l
    self.b = b

  def area(self):
    return self.l*self.b

# %%
rectangle = Rectangle(4,5)

# %%
rectangle.area()
# Out:
# 20

# %%
# Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute

class Vehicle:
  def __init__(self, vehicle_type):
    self.vehicle_type = vehicle_type

class Car(Vehicle):
  def __init__(self,vehicle_type,brand):
    super().__init__(vehicle_type)
    self.brand = brand

class ElectricCar:
  def _init__(self, vehicle_type, brand, battery):
    super().__init__(vehicle_type, brand)
    self.battery = battery

# %%
# Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.

class Bird:
  def fly(self):
    print("Bird can fly")

  class Sparrow:
    def fly(self):
      print("Sparrow can fly")

  class Penguin:
    def fly(self):
      print("Penguin can't fly")

# %%
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance


class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: {amount}")
        else:
            print("Invalid deposit amount")

    def withdraw(self, amount):
        if amount > 0 and amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: {amount}")
        else:
            print("Insufficient balance or invalid amount")

    def check_balance(self):
        print("Current Balance:", self.__balance)

# %%
# Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.

class MathOperations:

    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# %%
# Implement a class Person with a class method to count the total number of persons created.

class Person:
    total_persons = 0

    def __init__(self, name):
        self.name = name
        Person.total_persons += 1

    @classmethod
    def get_total_persons(cls):
        return cls.total_persons

# %%
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator"

class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades   # list of grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

# %%
class Rectangle:
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# %%
class Employee:
    def calculate_salary(self, hours_worked, hourly_rate):
        return hours_worked * hourly_rate


# Derived class
class Manager(Employee):
    def calculate_salary(self, hours_worked, hourly_rate, bonus):
        base_salary = super().calculate_salary(hours_worked, hourly_rate)
        return base_salary + bonus

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# %%
from abc import ABC, abstractmethod

# Abstract base class
class Animal(ABC):

    @abstractmethod
    def sound(self):
        pass


class Cow(Animal):
    def sound(self):
        print("Cow says Moo")


class Sheep(Animal):
    def sound(self):
        print("Sheep says Baa")

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year Published: {self.year_published}"
