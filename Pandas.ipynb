# %% [markdown]
# What is NumPy, and why is it widely used in Python
# Numpy is a internal libraray of python which is based upon language C. It is used to store homogenous data.
#
# It is widely used during the analysisis because it is pretty fast as compared to another tools. It can store only homogeneous data in multiple dimenions.
#
#
# How does broadcasting work in NumPy
# Broadcasting allows NumPy to automatically expand the smaller array so it matches the shape of the larger array during operations like addition, subtraction, multiplication, etc.
#
#
# What is a Pandas DataFrame
# Pandas is a internal libraray built inside python and it uses his internal data which is known as Pandas DataFrame. It is very fast, efficient to use for analysis
#
# Explain the use of the groupby() method in Pandas
# Groupby function are used to analyze the data in pandas on multiple level. If someone need to analysze total sales/number of sales of a year, we will group the data month-wise o yearly to get the short summary
#
# Why is Seaborn preferred for statistical visualizations
# Seaborn is preferred over the statistical visualizations because it is very easy to use, fast computations for visualizations and it can create multiple and user friendly plots as compared to statstical tools
#
# What are the differences between NumPy arrays and Python lists
# Diffrences between Numpy and Python Lists:
#
# 1. Python lists are 1-dimensional, however, Numpy arrays are multi-dimensional
# 2. Python lists are heterogenous in nature, but Numpy arrays are homogeneous in nature
#
# What is a heatmap, and when should it be used
# A heatmap is a data visualization technique that represents values in a dataset using colors. It is commonly used to show the co-relation in 2 varibles usually
#
# What does the term “vectorized operation” mean in NumPy
# In NumPy, a vectorized operation means performing computations on entire arrays at once (element-wise) without using explicit Python loops.
#
# How does Matplotlib differ from Plotly
# Matplotlib and plotly both are used for data visulization in python. However, Matplotlib are only capable of creating static visualization, but plotly used to generate visualization tools which can be interactive and show the different interfaces while visualizing data
#
#  What is the significance of hierarchical indexing in Pandas
# Hierarchical indexing is very useful in pandas because it helps the to retrieve the data in proper sequence. We can also filter data or make changes in it.
#
# What is the role of Seaborn’s pairplot() function
# Seaborn’s pairplot is used to show the relationship of multiple numerical columns with each other at once.
#
# What is the purpose of the describe() function in Pandas
# The describe() function in Pandas is used to generate summary statistics of a dataset, giving a quick overview of the data’s distribution, central tendency, and variance.
#
# Why is handling missing data important in Pandas
# Handling missing data is very important concept in pandas because we will not be able to define a proper conclusion due to missing values.
# Suppose a column which has 50% values missing, so we will not be able to perform any find of analysis on int
#
# What are the benefits of using Plotly for data visualization
# Plotly is a visualization tool which is used to create different types of graph. It is very useful as compared to matplotlib and seaborn because plotly provides you the flexibity to perform a live interaction with visualization
#
# How does NumPy handle multidimensional arrays
# NumPy handles multidimensional arrays using the ndarray (N-dimensional array) object, which stores data in a structured, efficient, and flexible way.
#
# What is the role of Bokeh in data visualization
# Bokeh is a Python data visualization library used to create interactive, web-ready visualizations that run directly in web browsers.
#
# Explain the difference between apply() and map() in Pandas
# Apply() function is used put some functionality into a data, however, map() is used to put functionality into data with already created function
#
# What are some advanced features of NumPy
# NumPy offers advanced features like broadcasting, vectorization, linear algebra, random sampling, and FFT for efficient numerical computation.
#
# How does Pandas simplify time series analysis
# Pandas are widely used in time series analysis because it provides various function like createing different columns like year, month day and many more functions to analyze the data
#
# What is the role of a pivot table in Pandas
# Pivot is used to summarize the data in 2 different level and it makes data interpretation very easy
#
# Why is NumPy’s array slicing faster than Python’s list slicing
# Numpy's array slicing is much faster than python list because it stores only homogeneous data and that makes slicing very easy
#
# What are some common use cases for Seaborn?
#
# Seaborn is mainly used for statistical data visualization.
#
#
# Exploratory Data Analysis (EDA)
#
# Correlation analysis (heatmaps)
#
# Distribution analysis (histplot, kdeplot)
#
# Relationship analysis (scatter, pairplot)
#
# Categorical comparisons (boxplot, violinplot)
#
# Visualizing patterns in ML datasets

# %%
# <A How do you create a 2D NumPy array and calculate the sum of each row)
import numpy as np
a = np.array([[2,3,4],[4,2,4],[3,4,5]])
row_sum = a.sum(axis = 1)
print(row_sum)
# Out:
# [ 9 10 12]

# %%
#7A Write a Pandas script to find the mean of a specific column in a DataFrame
import pandas as pd
a = pd.DataFrame(np.random.randn(50))
avg_value = np.mean(a)
print(avg_value)
# Out:
# -0.026910015994083925

# %%
#  Create a scatter plot using Matplotlib
x = np.random.randn(1,100)
y = np.random.randn(1,100)

import matplotlib.pyplot as plt
plt.scatter(x,y, marker = "*", color = "maroon")
plt.xlabel("X-Axis")
plt.ylabel("Y-axis")
plt.show()

# %%
# CA How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap
df.head(2)
x = df["median_income"]
y = df["households"]
df1 = pd.DataFrame(x,y)
sns.heatmap(data = df1)
# Out:
# <Axes: ylabel='households'>

# %%
# Generate a bar plot using Plotly

import plotly.graph_objects as go
import plotly.express as px

students = ["A","B","C"]
marks = [10,34,22]
fig = go.Figure()
fig.add_trace(go.Bar(x = students, y = marks ))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Create a DataFrame and add a new column based on an existing column
df.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0

# %%
#Write a program to perform element-wise multiplication of two NumPy arrays
import numpy as np
a = np.array([1, 2, 3, 4])
b = np.array([5, 6, 7, 8])

result = a * b
print(result)
# Out:
# [ 5 12 21 32]

# %%
#Create a line plot with multiple lines using Matplotlib

import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y1 = [10, 20, 30, 40, 50]
y2 = [8, 18, 21, 38, 48]
y3 = [5, 11, 24, 33, 45]

plt.plot(x, y1, label="Line 1")
plt.plot(x, y2, label="Line 2")
plt.plot(x, y3, label="Line 3")
plt.show()

# %%
# Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold
import pandas as pd

df = pd.DataFrame([1, 2, 3, 4, 5], columns = ["col1"])
y1 = [10, 20, 30, 40, 50]
y2 = [8, 18, 21, 38, 48]
y3 = [5, 11, 24, 33, 45]

df["col2"] = y1
df["col3"] = y2
df["col4"] = y3

df[df["col2"]> 6]
# Out:
#    col1  col2  col3  col4
# 0     1    10     8     5
# 1     2    20    18    11
# 2     3    30    21    24
# 3     4    40    38    33
# 4     5    50    48    45

# %%
#Create a histogram using Seaborn to visualize a distribution
import seaborn as sns
sns.histplot(data = df, x = df["median_income"], bins = 10)
plt.show()

# %%
# <<A Perform matrix multiplication using NumPy

a = np.array([[1, 2],
              [3, 4]])

b = np.array([[5, 6],
              [7, 8]])

result = a@b
print(result)
# Out:
# [[19 22]
#  [43 50]]

# %%
#<7A Use Pandas to load a CSV file and display its first 5 rows
import pandas as pd
df= pd.read_csv("/content/sample_data/california_housing_test.csv")
df.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
# <>A Create a 3D scatter plot using Plotly.
import plotly.graph_objects as go
import plotly.express as px

fig = go.Figure()

fig.add_trace(go.Scatter3d(x = df["total_rooms"],
                           y = df["total_bedrooms"],
                           z = df["median_income"]))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
